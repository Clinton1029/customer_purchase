# %% [markdown]
# <a href="https://colab.research.google.com/github/Clinton1029/customer_purchase/blob/main/customer_purchase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import pandas for data handling
import pandas as pd

# Import os for file system operations
import os

# files module lets you manually upload files to Colab
from google.colab import files

# %%
# This will open a file chooser dialog to select your Excel file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-108ecd3d-4b80-496f-9563-4301f336b1e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-108ecd3d-4b80-496f-9563-4301f336b1e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load your dataset using pandas
customer_purchase= pd.read_excel("Customer Purchase.xlsx")

# Display the first few rows to confirm it loaded correctly
customer_purchase.head()
# Out:
#   Unique ID  Age  Gender   Item Purchased     Category  Purchase Amount (USD)  \
# 0      C001   24    Male           Hoodie      Apparel                  45.00
# 1      C002   31  Female    Running Shoes     Footwear                  89.99
# 2      C003   19    Male  Graphic T-Shirt      Apparel                  22.50
# 3      C004   28  Female          Handbag  Accessories                  54.00
# 4      C005   35    Male   Leather Jacket      Apparel                 120.00
#
#   Location      Size       Color  Season
# 0  Nairobi         L       Black  Winter
# 1  Mombasa        38       White  Summer
# 2   Kisumu         M        Blue  Spring
# 3  Eldoret  One Size       Brown  Autumn
# 4   Nakuru        XL  Dark Brown  Winter
